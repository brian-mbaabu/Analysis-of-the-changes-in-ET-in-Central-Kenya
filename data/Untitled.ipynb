# %%
import rioxarray as rio

# %%
data = rio.open_rasterio('y2013_viirsSSEBopETv6_actual_mm.tif')

# %%
data
# Out:
# <xarray.DataArray (band: 1, y: 8082, x: 7772)>
# [62813304 values with dtype=int16]
# Coordinates:
#   * band         (band) int32 1
#   * x            (x) float64 -20.0 -19.99 -19.98 -19.97 ... 54.98 54.99 55.0
#   * y            (y) float64 40.0 39.99 39.98 39.97 ... -37.98 -37.99 -38.0
#     spatial_ref  int32 0
# Attributes: (12/13)
#     AREA_OR_POINT:           Area
#     DataType:                Generic
#     BandName:                Band_1
#     RepresentationType:      THEMATIC
#     STATISTICS_MAXIMUM:      2624
#     STATISTICS_MEAN:         460.13518047579
#     ...                      ...
#     STATISTICS_SKIPFACTORX:  1
#     STATISTICS_SKIPFACTORY:  1
#     STATISTICS_STDDEV:       413.97461904783
#     _FillValue:              -9999
#     scale_factor:            1.0
#     add_offset:              0.0
